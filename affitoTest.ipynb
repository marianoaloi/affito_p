# %%
internalJSON = {
  "realEstate": {
    "visibility": "premium",
    "dataType": "list-real-estate",
    "id": 120466908,
    "uuid": "fd0f2076-e7f8-5b50-86a5-6e0ed2ca3904",
    "advertiser": {
      "agency": {
        "id": 234946,
        "type": "agency",
        "showOnlyAgentPhone": False,
        "phones": [
          {
            "type": "vTel1",
            "value": "0432 138 2816"
          }
        ],
        "bookableVisit": {
          "isVisitBookable": True,
          "virtualVisitEnabled": False
        },
        "isPaid": True,
        "label": "agenzia",
        "displayName": "Agenzia ImmobiGo",
        "guaranteed": False,
        "showAgentPhone": False,
        "showLogo": True,
        "imageUrls": {
          "small": "https://pic.im-cdn.it/imagenoresize/1164412090.jpg",
          "large": "https://pic.im-cdn.it/imagenoresize/1164412092.jpg"
        },
        "agencyUrl": "https://www.immobiliare.it/agenzie-immobiliari/234946/immobigo-tavagnacco/",
        "showExternalLink": False
      },
      "supervisor": {
        "type": "agent",
        "imageGender": "male",
        "phones": [
          {
            "type": "vTel1",
            "value": "0432 138 2816"
          }
        ],
        "imageType": "agent",
        "displayName": "Agenzia ImmobiGo",
        "label": "agente immobiliare",
        "imageUrl": "https://pic.im-cdn.it/agenti/259840/1683126556/80.jpg"
      },
      "hasCallNumbers": True
    },
    "contract": "rent",
    "isNew": False,
    "luxury": False,
    "price": {
      "visible": True,
      "value": 950,
      "formattedValue": "€ 950/mese",
      "priceRange": "501 - 1000 &euro;"
    },
    "properties": [
      {
        "multimedia": {
          "photos": [
            {
              "id": 1703877768,
              "caption": "Cucina",
              "urls": {
                "small": "https://pwm.im-cdn.it/image/1703877768/xxs-c.jpg"
              }
            },
            {
              "id": 1703877812,
              "caption": "Camera da letto",
              "urls": {
                "small": "https://pwm.im-cdn.it/image/1703877812/xxs-c.jpg"
              }
            },
            {
              "id": 1703877900,
              "caption": "Camera da letto",
              "urls": {
                "small": "https://pwm.im-cdn.it/image/1703877900/xxs-c.jpg"
              }
            },
            {
              "id": 1703877590,
              "caption": "Ingresso",
              "urls": {
                "small": "https://pwm.im-cdn.it/image/1703877590/xxs-c.jpg"
              }
            },
            {
              "id": 1703877548,
              "caption": "Camera da letto",
              "urls": {
                "small": "https://pwm.im-cdn.it/image/1703877548/xxs-c.jpg"
              }
            },
            {
              "id": 1703877722,
              "caption": "Camera da letto",
              "urls": {
                "small": "https://pwm.im-cdn.it/image/1703877722/xxs-c.jpg"
              }
            },
            {
              "id": 1703877630,
              "caption": "Bagno",
              "urls": {
                "small": "https://pwm.im-cdn.it/image/1703877630/xxs-c.jpg"
              }
            },
            {
              "id": 1703877860,
              "caption": "Bagno",
              "urls": {
                "small": "https://pwm.im-cdn.it/image/1703877860/xxs-c.jpg"
              }
            }
          ],
          "virtualTours": [],
          "hasMultimedia": True
        },
        "bathrooms": "1",
        "floor": {
          "abbreviation": "2",
          "value": "2°",
          "floorOnlyValue": "2",
          "ga4FloorValue": "2"
        },
        "ga4Condition": "Ottimo / Ristrutturato",
        "price": {
          "visible": True,
          "value": 950,
          "formattedValue": "€ 950/mese",
          "priceRange": "501 - 1000 &euro;"
        },
        "rooms": "4",
        "surface": "87 m²",
        "typology": {
          "id": 14,
          "name": "Appartamento"
        },
        "typologyGA4Translation": "Appartamento",
        "ga4features": [
          "porta blindata",
          "armadio a muro",
          "impianto tv con parabola satellitare",
          "arredato",
          "esposizione doppia"
        ],
        "ga4Heating": "Autonomo",
        "caption": "Appartamento bicamere ristrutturato in centro storico",
        "category": {
          "id": 1,
          "name": "Residenziale"
        },
        "photo": {
          "id": 1703877768,
          "caption": "Cucina",
          "urls": {
            "small": "https://pwm.im-cdn.it/image/1703877768/xxs-c.jpg",
            "medium": "https://pwm.im-cdn.it/image/1703877768/m-c.jpg",
            "large": "https://pwm.im-cdn.it/image/1703877768/xxl.jpg"
          }
        },
        "bedRoomsNumber": "2",
        "location": {
          "address": "Via San Francesco d'Assisi",
          "latitude": 46.0617,
          "longitude": 13.2384,
          "marker": "marker",
          "region": "Friuli Venezia Giulia",
          "province": "Udine",
          "macrozone": "Centro",
          "microzone": "Duomo - Aquileia",
          "city": "Udine",
          "nation": {
            "id": "IT",
            "name": "Italia"
          }
        },
        "featureList": [
          {
            "type": "rooms",
            "label": "4 locali",
            "compactLabel": "4"
          },
          {
            "type": "surface",
            "label": "87 m²"
          },
          {
            "type": "bathrooms",
            "label": "1 bagno",
            "compactLabel": "1"
          },
          {
            "type": "floor",
            "label": "Piano 2",
            "compactLabel": "2"
          },
          {
            "type": "elevator",
            "label": "No Ascensore",
            "compactLabel": "No"
          },
          {
            "type": "furniture",
            "label": "Arredato"
          }
        ]
      }
    ],
    "title": "Quadrilocale via San Francesco d'Assisi, Duomo - Aquileia, Udine",
    "type": "ad",
    "typology": {
      "id": 14,
      "name": "Appartamento"
    },
    "hasMainProperty": False,
    "isProjectLike": False,
    "isMosaic": False
  },
  "seo": {
    "anchor": "Quadrilocale via San Francesco d'Assisi, Duomo - Aquileia, Udine",
    "url": "https://www.immobiliare.it/annunci/120466908/"
  },
  "idGeoHash": "u21qj1rb",
  "mLastUpdate": 1753356249.9601393,
  "stateMaloi": 0,
  "deleted": True
}

# %%
id = internalJSON["realEstate"]["id"]

import os
from pymongo import MongoClient,server_api


MONGO_URI =  "mongodb+srv://cluster0.7qska.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority&appName=Cluster0"
DATABASE_NAME = "udine"
COLLECTION_NAME = "affito"

print(f"Connecting to MongoDB database: '{DATABASE_NAME}'...")
client = MongoClient(MONGO_URI,
                tls=True,
                tlsCertificateKeyFile= os.path.dirname(__file__) + '/X509-cert-2864290664025085959.pem',
                server_api=server_api.ServerApi('1'))
db = client[DATABASE_NAME]
collection = db[COLLECTION_NAME]
print("MongoDB connection successful.")
# Out:
# Connecting to MongoDB database: 'udine'...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#       9 COLLECTION_NAME = "affito"
#      11 print(f"Connecting to MongoDB database: '{DATABASE_NAME}'...")
#      12 client = MongoClient(MONGO_URI,
#      13                 tls=True,
# ---> 14                 tlsCertificateKeyFile= os.path.dirname(__file__) + '/X509-cert-2864290664025085959.pem',
#      15                 server_api=server_api.ServerApi('1'))
#      16 db = client[DATABASE_NAME]
#      17 collection = db[COLLECTION_NAME]
#
# NameError: name '__file__' is not defined
